# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
real = pd.read_csv("d:\\data\\realistate.csv")

# %%
real.head(5)
# Out:
#    No  X1 transaction date  X2 house age  \
# 0   1             2012.917          32.0
# 1   2             2012.917          19.5
# 2   3             2013.583          13.3
# 3   4             2013.500          13.3
# 4   5             2012.833           5.0
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                84.87882                               10
# 1                               306.59470                                9
# 2                               561.98450                                5
# 3                               561.98450                                5
# 4                               390.56840                                5
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0     24.98298     121.54024                        37.9
# 1     24.98034     121.53951                        42.2
# 2     24.98746     121.54391                        47.3
# ...

# %%
real['X1 transaction date'] = real['X1 transaction date'].astype(int)

# %%
real.describe()
# Out:
#                No  X1 transaction date  X2 house age  \
# count  414.000000           414.000000    414.000000
# mean   207.500000          2012.695652     17.712560
# std    119.655756             0.460687     11.392485
# min      1.000000          2012.000000      0.000000
# 25%    104.250000          2012.000000      9.025000
# 50%    207.500000          2013.000000     16.100000
# 75%    310.750000          2013.000000     28.150000
# max    414.000000          2013.000000     43.800000
#
#        X3 distance to the nearest MRT station  \
# count                              414.000000
# mean                              1083.885689
# std                               1262.109595
# min                                 23.382840
# 25%                                289.324800
# 50%                                492.231300
# 75%                               1454.279000
# max                               6488.021000
#
# ...

# %%
real.dtypes
# Out:
# No                                          int64
# X1 transaction date                         int32
# X2 house age                              float64
# X3 distance to the nearest MRT station    float64
# X4 number of convenience stores             int64
# X5 latitude                               float64
# X6 longitude                              float64
# Y house price of unit area                float64
# dtype: object

# %%
#no  column is not required so we can drop/delete it

# %%
del real['No']

# %%
real.iloc[:,1:7]= real.iloc[:,1:7].astype(int)

# %%
real.head(5)
# Out:
#    X1 transaction date  X2 house age  X3 distance to the nearest MRT station  \
# 0                 2012            32                                      84
# 1                 2012            19                                     306
# 2                 2013            13                                     561
# 3                 2013            13                                     561
# 4                 2012             5                                     390
#
#    X4 number of convenience stores  X5 latitude  X6 longitude  \
# 0                               10           24           121
# 1                                9           24           121
# 2                                5           24           121
# 3                                5           24           121
# 4                                5           24           121
#
#    Y house price of unit area
# 0                          37
# 1                          42
# 2                          47
# ...

# %%
import seaborn as sns

# %%
sns.countplot(x ='X1 transaction date',data=real,palette='hls')

# %%
# check for outliers

# %%
real.boxplot(column='X2 house age')

# %%
real.boxplot(column ='X3 distance to the nearest MRT station')

# %%
real.boxplot(column ='X4 number of convenience stores')

# %%
real.boxplot(column='X5 latitude')

# %%
real.boxplot(column='X6 longitude')

# %%
real.boxplot(column='Y house price of unit area')

# %%
#check for correlation of datas

# %%
real.corr()
# Out:
#                                         X1 transaction date  X2 house age  \
# X1 transaction date                                1.000000      0.050003
# X2 house age                                       0.050003      1.000000
# X3 distance to the nearest MRT station             0.016521      0.024794
# X4 number of convenience stores                   -0.005586      0.048855
# X5 latitude                                        0.046085     -0.032573
# X6 longitude                                            NaN           NaN
# Y house price of unit area                         0.082638     -0.208933
#
#                                         X3 distance to the nearest MRT station  \
# X1 transaction date                                                   0.016521
# X2 house age                                                          0.024794
# X3 distance to the nearest MRT station                                1.000000
# ...

# %%
import seaborn as sns

# %%
correla = real.corr()

# %%
coll = correla.index

# %%
plt.figure(figsize=(20,20))
sns.heatmap(real[coll].corr(),annot=True,cmap="BuGn")

# %%
sns.pairplot(real)

# %%
#data cleansing

# %%
real['X3 distance to the nearest MRT station'].describe()
# Out:
# count     414.000000
# mean     1083.376812
# std      1262.159441
# min        23.000000
# 25%       289.000000
# 50%       492.000000
# 75%      1453.500000
# max      6488.000000
# Name: X3 distance to the nearest MRT station, dtype: float64

# %%
real['X3 distance to the nearest MRT station']=real['X3 distance to the nearest MRT station'].clip(23,1453)

# %%
real.boxplot(column='X3 distance to the nearest MRT station')

# %%
# correlation  we removed

# %%
del real['X5 latitude']

# %%
del real['X6 longitude']

# %%
# split data into x and y

# %%
x = real['X1 transaction date','X2 house age','X3 distance to the nearest MRT station','X4 number of convenience stores' ]
y =real['Y house price of unit area']

# %%
from sklearn import linear_model

# %%
from sklearn.metrics import mean_squared_error

# %%
import math

# %%
import scipy.stats as stats

# %%
regression =linear_model.LinearRegression()

# %%
regression.fit(x,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print('Intercept: \n', regression.intercept_)
print('Coefficients: \n', regression.coef_)
# Out:
# Intercept:
#  [-6110.16239025]
# Coefficients:
#  [[ 3.05695427 -0.2592746  -0.00540439  1.30079846]]

# %%
predicted_value=regression.predict(x)

# %%
print(predicted_value)
# Out:
# [[44.68683383]
#  [45.5568307 ]
#  [43.58811945]
#  [43.58811945]
#  [43.5295125 ]
#  [30.7625316 ]
#  [37.35292346]
#  [44.55479839]
#  [ 6.96085178]
#  [33.3452605 ]
#  [33.78324382]
#  [53.15170278]
#  [40.90406803]
#  [27.10386988]
#  [39.02847428]
#  [33.88440396]
#  [49.71326835]
#  [35.43119908]
#  [47.75573816]
#  [49.15161865]
#  [34.05687073]
#  [48.49157792]
#  [30.75058974]
#  [48.49157792]
#  [35.98393703]
#  [30.53286611]
#  [44.08589241]
#  [45.90619416]
#  [40.75329097]
#  [45.73824983]
#  [12.5822594 ]
#  [37.86025561]
#  [29.49990146]
#  [45.39733876]
#  [44.53817547]
#  [18.07148581]
#  [28.94386439]
#  [34.3260932 ]
#  [44.33823936]
#  [44.28028953]
#  [18.05527264]
#  [17.36391909]
#  [37.8517881 ]
#  [36.6520122 ]
#  [45.29066443]
#  [41.92171955]
#  [47.24674667]
#  [34.85553468]
#  [12.37675652]
#  [ 9.83764471]
#  [40.4779393 ]
#  [27.24892897]
#  [31.32065585]
#  [43.9610223 ]
#  [44.28028953]
#  [26.123001  ]
#  [43.33185687]
#  [48.45472461]
# ...

# %%
error = predicted_value - y

# %%
print(error)
# Out:
#      Y house price of unit area
# 0                      7.686834
# 1                      3.556831
# 2                     -3.411881
# 3                    -10.411881
# 4                      0.529512
# ..                          ...
# 409                    3.055273
# 410                    0.354023
# 411                    5.817494
# 412                   -4.645702
# 413                   -9.848297
#
# [414 rows x 1 columns]

# %%
 Terror=np.sum(predicted_value)-np.sum(y)

# %%
print(Terror)
# Out:
# Y house price of unit area    3.583409e-10
# dtype: float64

# %%
 mes = mean_squared_error(y,predicted_value)

# %%
rmse = math.sqrt(mes)

# %%
print(rmse)
# Out:
# 9.135170826465092

# %%
# split data into train and test

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
x.head()
# Out:
#    X1 transaction date  X2 house age  X3 distance to the nearest MRT station  \
# 0                 2012            32                                      84
# 1                 2012            19                                     306
# 2                 2013            13                                     561
# 3                 2013            13                                     561
# 4                 2012             5                                     390
#
#    X4 number of convenience stores
# 0                               10
# 1                                9
# 2                                5
# 3                                5
# 4                                5

# %%
y.head()
# Out:
#    Y house price of unit area
# 0                          37
# 1                          42
# 2                          47
# 3                          54
# 4                          43

# %%
regression.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
predicted_value1 = regression.predict(x_test)

# %%
print(predicted_value1)
# Out:
# [[39.01862968]
#  [52.75106994]
#  [40.8084663 ]
#  [53.26009131]
#  [21.60801707]
#  [27.18905139]
#  [47.1667494 ]
#  [43.96235179]
#  [39.17708691]
#  [33.51623363]
#  [29.57598332]
#  [40.87620039]
#  [52.75106994]
#  [34.67569066]
#  [35.04469651]
#  [43.5687562 ]
#  [51.69885863]
#  [40.08855562]
#  [23.02796833]
#  [35.29744582]
#  [38.86341879]
#  [47.84455535]
#  [33.37739693]
#  [37.98945462]
#  [37.88181996]
#  [40.65121516]
#  [39.14713903]
#  [19.98231657]
#  [30.92817949]
#  [33.1568022 ]
#  [35.0914323 ]
#  [43.91360158]
#  [42.44899235]
#  [18.85639295]
#  [42.94208388]
#  [44.21859322]
#  [34.67569066]
#  [38.1375912 ]
#  [44.05191269]
#  [39.41706266]
#  [36.75046472]
#  [46.95059493]
#  [49.52688682]
#  [33.99975073]
#  [42.77321073]
#  [48.421781  ]
#  [45.28294144]
#  [47.49789265]
#  [28.27257431]
#  [34.91876623]
#  [50.97812975]
#  [44.1332463 ]
#  [27.45260892]
#  [49.65603133]
#  [49.52688682]
#  [33.7983307 ]
#  [48.18126308]
#  [38.49212983]
# ...

# %%
error1 = predicted_value1 - y_test

# %%
print(error1)
# Out:
#      Y house price of unit area
# 179                   -2.981370
# 213                   -5.248930
# 28                    -6.191534
# 236                   -7.739909
# 307                   -2.391983
# ..                          ...
# 285                  -19.084458
# 357                    8.979937
# 408                    3.313453
# 113                   38.414308
# 57                    -5.062748
#
# [83 rows x 1 columns]

# %%
terror1 = np.sum(predicted_value1)- np.sum(y_test)

# %%
print(terror1)
# Out:
# Y house price of unit area    17.811092
# dtype: float64

# %%
mes1 = mean_squared_error(y_test,predicted_value1)

# %%
print(mes1)
# Out:
# 92.00979706691221

# %%
rmse=math.sqrt(mes1)

# %%
print(rmse)
# Out:
# 9.592173740446542

# %%
#plot

# %%
sns.residplot(predicted_value.reshape(-1),'Y house price of unit area', data=real,lowess=True,
                                  line_kws={'color': 'red', 'lw': 1, 'alpha': 1})
plt.xlabel("Fitted values")
plt.title('Residual plot')
# Out:
# Text(0.5, 1.0, 'Residual plot')

# %%
residuals = real["Y house price of unit area"] - predicted_value.reshape(-1)
residuals
plt.figure(figsize=(7,7))
stats.probplot(residuals, dist="norm", plot=plt)
plt.title("Normal Q-Q Plot")
# Out:
# Text(0.5, 1.0, 'Normal Q-Q Plot')

# %%
model_norm_residuals_abs_sqrt=np.sqrt(np.abs(residuals))

plt.figure(figsize=(7,7))
sns.regplot(predicted_value.reshape(-1), model_norm_residuals_abs_sqrt,
              scatter=True,
              lowess=True,
              line_kws={'color': 'red', 'lw': 1, 'alpha': 0.8})
plt.ylabel("Standarized residuals")
plt.xlabel("Fitted value")
# Out:
# Text(0.5, 0, 'Fitted value')
